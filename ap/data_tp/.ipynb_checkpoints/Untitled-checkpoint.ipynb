# %% [markdown]
# # Data TP

# %% [markdown]
# ## Import librairies and databases

# %%
import pandas
import numpy

# %%
dataset = pandas.read_csv('.\\google\\data\\train.txt', delimiter=" ", names=["heads","tails","relation"])

# %%
dataset.describe()
# Out:
#        heads       tails       relation
# count    573         573            573
# unique   474         506             14
# top     slow  california  capital-world
# freq       5          12            116

# %%
dataset.shape
# Out:
# (573, 3)

# %%
dataset.head()
# Out:
#     heads        tails                  relation
# 0  madrid        spain  capital-common-countries
# 1  ottawa       canada  capital-common-countries
# 2   cairo        egypt  capital-common-countries
# 3   paris       france  capital-common-countries
# 4    bern  switzerland  capital-common-countries

# %% [markdown]
# ## Load Vectors

# %%
def load_vectors(file_path):
    resultDict = dict()
    with open(file_path) as f:
        raw_text = f.read()
        for raw_line in raw_text.split("\n")[:-1]:
            ind = raw_line.index(" ")
            resultDict[raw_line[:ind]] = raw_line[ind+1:]
        
    return resultDict

def formatPattern(algo, columns_value, file_name):
    return '.\\google\\{}\\subspaces\\{}\\{}.txt'.format(algo, columns_value, file_name)

# %%
vectors = {"heads": dict(), "tails": dict()}

for file_name in vectors.keys():
    for columns_value in set(dataset['relation'].values):
        file_dir = formatPattern('gloveCC', columns_value, file_name)
        vectors[file_name][columns_value] = load_vectors(file_dir)

# %% [markdown]
# ## Replace values in dataframe

# %%
def replace_values(dataframe, vectorsDict):
    resultdf = dataframe.to_dict()
    for indice in range(len(resultdf['relation'])):
        head = resultdf['heads'][indice]
        tail = resultdf['tails'][indice]
        relation = resultdf['relation'][indice]
        
        try:
            resultdf['heads'][indice] = vectorsDict['heads'][relation][head]
        except:
            print("no vector for (relation:%s, head:%s) " % (relation, head))
        
        try:
            resultdf['tails'][indice] = vectorsDict['tails'][relation][tail]
        except:
            print("no vector for (relation:%s, tails:%s) " % (relation, tail))
        
    return resultdf

# %%
dataset2 = replace_values(dataset, vectors)
# Out:
# no vector for (relation:capital-common-countries, tails:spain)
# no vector for (relation:capital-common-countries, tails:canada)
# no vector for (relation:capital-common-countries, tails:egypt)
# no vector for (relation:capital-common-countries, tails:france)
# no vector for (relation:capital-common-countries, tails:switzerland)
# no vector for (relation:capital-common-countries, tails:iraq)
# no vector for (relation:capital-common-countries, tails:italy)
# no vector for (relation:capital-common-countries, tails:thailand)
# no vector for (relation:capital-common-countries, tails:afghanistan)
# no vector for (relation:capital-common-countries, tails:japan)
# no vector for (relation:capital-common-countries, tails:greece)
# no vector for (relation:capital-common-countries, tails:germany)
# no vector for (relation:capital-common-countries, tails:russia)
# no vector for (relation:capital-common-countries, tails:vietnam)
# no vector for (relation:capital-common-countries, tails:china)
# no vector for (relation:capital-common-countries, tails:norway)
# no vector for (relation:capital-common-countries, tails:pakistan)
# no vector for (relation:capital-common-countries, tails:sweden)
# no vector for (relation:capital-common-countries, tails:england)
# no vector for (relation:capital-common-countries, tails:iran)
# no vector for (relation:capital-common-countries, tails:cuba)
# no vector for (relation:capital-common-countries, tails:australia)
# no vector for (relation:capital-common-countries, tails:finland)
# no vector for (relation:capital-world, tails:chile)
# no vector for (relation:capital-world, tails:jordan)
# no vector for (relation:capital-world, tails:nepal)
# no vector for (relation:capital-world, tails:nicaragua)
# no vector for (relation:capital-world, tails:madagascar)
# no vector for (relation:capital-world, tails:sudan)
# no vector for (relation:capital-world, tails:gabon)
# no vector for (relation:capital-world, tails:slovenia)
# no vector for (relation:capital-world, tails:malta)
# no vector for (relation:capital-world, tails:rwanda)
# no vector for (relation:capital-world, tails:germany)
# no vector for (relation:capital-world, tails:greece)
# no vector for (relation:capital-world, tails:bahamas)
# no vector for (relation:capital-world, tails:georgia)
# no vector for (relation:capital-world, tails:mozambique)
# no vector for (relation:capital-world, tails:zimbabwe)
# no vector for (relation:capital-world, tails:kyrgyzstan)
# no vector for (relation:capital-world, tails:syria)
# no vector for (relation:capital-world, tails:kazakhstan)
# no vector for (relation:capital-world, tails:guinea)
# no vector for (relation:capital-world, tails:liberia)
# no vector for (relation:capital-world, tails:canada)
# no vector for (relation:capital-world, tails:eritrea)
# no vector for (relation:capital-world, tails:hungary)
# no vector for (relation:capital-world, tails:thailand)
# no vector for (relation:capital-world, tails:serbia)
# no vector for (relation:capital-world, tails:china)
# no vector for (relation:capital-world, tails:ukraine)
# no vector for (relation:capital-world, tails:iraq)
# no vector for (relation:capital-world, tails:uzbekistan)
# no vector for (relation:capital-world, tails:jamaica)
# no vector for (relation:capital-world, tails:libya)
# no vector for (relation:capital-world, tails:vietnam)
# no vector for (relation:capital-world, tails:fiji)
# no vector for (relation:capital-world, tails:angola)
# no vector for (relation:capital-world, tails:ireland)
# no vector for (relation:capital-world, tails:portugal)
# no vector for (relation:capital-world, tails:tajikistan)
# no vector for (relation:capital-world, tails:poland)
# no vector for (relation:capital-world, tails:uruguay)
# no vector for (relation:capital-world, tails:denmark)
# no vector for (relation:capital-world, tails:peru)
# no vector for (relation:capital-world, tails:bahrain)
# no vector for (relation:capital-world, tails:turkey)
# no vector for (relation:capital-world, tails:kenya)
# no vector for (relation:capital-world, tails:romania)
# no vector for (relation:capital-world, tails:dominica)
# no vector for (relation:capital-world, tails:philippines)
# no vector for (relation:capital-world, tails:nigeria)
# no vector for (relation:capital-world, tails:malawi)
# no vector for (relation:capital-world, tails:belarus)
# no vector for (relation:capital-world, head:funafuti)
# no vector for (relation:capital-world, tails:tuvalu)
# no vector for (relation:capital-world, tails:qatar)
# no vector for (relation:capital-world, tails:switzerland)
# no vector for (relation:capital-world, tails:burundi)
# no vector for (relation:capital-world, tails:uganda)
# no vector for (relation:capital-world, tails:somalia)
# no vector for (relation:capital-world, tails:azerbaijan)
# no vector for (relation:capital-world, tails:honduras)
# no vector for (relation:capital-world, tails:lithuania)
# no vector for (relation:capital-world, tails:gambia)
# no vector for (relation:capital-world, head:ashgabat)
# no vector for (relation:capital-world, tails:turkmenistan)
# no vector for (relation:capital-world, tails:suriname)
# no vector for (relation:capital-world, tails:egypt)
# no vector for (relation:capital-world, tails:ecuador)
# no vector for (relation:capital-world, tails:macedonia)
# no vector for (relation:capital-world, tails:belgium)
# no vector for (relation:capital-world, tails:ghana)
# no vector for (relation:capital-world, head:belmopan)
# no vector for (relation:capital-world, tails:belize)
# no vector for (relation:capital-world, tails:venezuela)
# no vector for (relation:capital-world, tails:afghanistan)
# no vector for (relation:capital-world, tails:armenia)
# no vector for (relation:capital-world, tails:norway)
# no vector for (relation:capital-world, tails:pakistan)
# no vector for (relation:capital-world, tails:guyana)
# no vector for (relation:capital-world, tails:albania)
# no vector for (relation:capital-world, tails:lebanon)
# no vector for (relation:capital-world, head:thimphu)
# no vector for (relation:capital-world, tails:bhutan)
# no vector for (relation:capital-world, tails:namibia)
# no vector for (relation:capital-world, head:niamey)
# no vector for (relation:capital-world, tails:niger)
# no vector for (relation:capital-world, tails:austria)
# no vector for (relation:capital-world, tails:moldova)
# no vector for (relation:capital-world, head:nouakchott)
# no vector for (relation:capital-world, tails:mauritania)
# no vector for (relation:capital-world, head:nuuk)
# no vector for (relation:capital-world, tails:greenland)
# no vector for (relation:capital-world, tails:croatia)
# no vector for (relation:capital-world, tails:russia)
# no vector for (relation:capital-world, tails:japan)
# no vector for (relation:capital-world, tails:cuba)
# no vector for (relation:capital-world, tails:morocco)
# no vector for (relation:capital-world, tails:finland)
# no vector for (relation:capital-world, tails:slovakia)
# no vector for (relation:capital-world, tails:france)
# no vector for (relation:capital-world, tails:bulgaria)
# no vector for (relation:capital-world, tails:australia)
# no vector for (relation:capital-world, head:podgorica)
# no vector for (relation:capital-world, tails:montenegro)
# no vector for (relation:capital-world, tails:samoa)
# no vector for (relation:capital-world, tails:sweden)
# no vector for (relation:capital-world, tails:botswana)
# no vector for (relation:capital-world, tails:oman)
# no vector for (relation:capital-world, tails:algeria)
# no vector for (relation:capital-world, tails:england)
# no vector for (relation:capital-world, tails:spain)
# no vector for (relation:capital-world, tails:indonesia)
# no vector for (relation:capital-world, head:vaduz)
# no vector for (relation:capital-world, tails:liechtenstein)
# no vector for (relation:capital-world, tails:taiwan)
# no vector for (relation:capital-world, tails:italy)
# no vector for (relation:capital-world, tails:cyprus)
# no vector for (relation:capital-world, tails:estonia)
# no vector for (relation:capital-world, tails:latvia)
# no vector for (relation:capital-world, tails:mali)
# no vector for (relation:capital-world, tails:senegal)
# no vector for (relation:capital-world, tails:laos)
# no vector for (relation:capital-world, tails:bangladesh)
# no vector for (relation:capital-world, tails:zambia)
# no vector for (relation:capital-world, tails:iran)
# no vector for (relation:capital-world, tails:tunisia)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:michigan)
# no vector for (relation:city-in-state, tails:oregon)
# no vector for (relation:city-in-state, tails:nebraska)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:pennsylvania)
# no vector for (relation:city-in-state, tails:florida)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:wisconsin)
# no vector for (relation:city-in-state, tails:colorado)
# no vector for (relation:city-in-state, tails:florida)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:kansas)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:arizona)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:arizona)
# no vector for (relation:city-in-state, tails:hawaii)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:kentucky)
# no vector for (relation:city-in-state, tails:massachusetts)
# no vector for (relation:city-in-state, tails:tennessee)
# no vector for (relation:city-in-state, tails:georgia)
# no vector for (relation:city-in-state, tails:louisiana)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:washington)
# no vector for (relation:city-in-state, tails:ohio)
# no vector for (relation:city-in-state, tails:florida)
# no vector for (relation:city-in-state, tails:florida)
# no vector for (relation:city-in-state, tails:alabama)
# no vector for (relation:city-in-state, tails:pennsylvania)
# no vector for (relation:city-in-state, tails:arizona)
# no vector for (relation:city-in-state, tails:wisconsin)
# no vector for (relation:city-in-state, tails:minnesota)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:nevada)
# no vector for (relation:city-in-state, tails:indiana)
# no vector for (relation:city-in-state, tails:arizona)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:maryland)
# no vector for (relation:city-in-state, tails:florida)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:illinois)
# no vector for (relation:city-in-state, tails:arizona)
# no vector for (relation:city-in-state, tails:alaska)
# no vector for (relation:city-in-state, tails:nevada)
# no vector for (relation:city-in-state, tails:texas)
# no vector for (relation:city-in-state, tails:ohio)
# no vector for (relation:city-in-state, tails:washington)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:florida)
# no vector for (relation:city-in-state, tails:tennessee)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:kentucky)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:arizona)
# no vector for (relation:city-in-state, tails:massachusetts)
# no vector for (relation:city-in-state, tails:washington)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:ohio)
# no vector for (relation:city-in-state, tails:ohio)
# no vector for (relation:city-in-state, tails:california)
# no vector for (relation:city-in-state, tails:oklahoma)
# no vector for (relation:currency, tails:dollar)
# no vector for (relation:currency, tails:ringgit)
# no vector for (relation:currency, tails:dollar)
# no vector for (relation:currency, tails:baht)
# no vector for (relation:currency, tails:litas)
# no vector for (relation:currency, tails:yen)
# no vector for (relation:currency, tails:forint)
# no vector for (relation:currency, tails:peso)
# no vector for (relation:currency, tails:dinar)
# no vector for (relation:currency, tails:dram)
# no vector for (relation:currency, tails:naira)
# no vector for (relation:currency, tails:euro)
# no vector for (relation:currency, tails:lats)
# no vector for (relation:currency, tails:denar)
# no vector for (relation:currency, tails:kwanza)
# no vector for (relation:currency, tails:rial)
# no vector for (relation:currency, tails:riel)
# no vector for (relation:currency, tails:zloty)
# no vector for (relation:currency, tails:ruble)
# no vector for (relation:currency, tails:krone)
# no vector for (relation:currency, tails:rupee)
# no vector for (relation:currency, tails:won)
# no vector for (relation:currency, tails:lev)
# no vector for (relation:currency, tails:peso)
# no vector for (relation:currency, tails:dong)
# no vector for (relation:currency, tails:leu)
# no vector for (relation:currency, tails:hryvnia)
# no vector for (relation:currency, tails:real)
# no vector for (relation:currency, tails:kuna)
# no vector for (relation:currency, tails:krona)
# no vector for (relation:family, tails:queen)
# no vector for (relation:family, tails:daughter)
# no vector for (relation:family, tails:aunt)
# no vector for (relation:family, tails:sister)
# no vector for (relation:family, tails:stepmother)
# no vector for (relation:family, tails:grandma)
# no vector for (relation:family, tails:niece)
# no vector for (relation:family, tails:granddaughter)
# no vector for (relation:family, tails:sisters)
# no vector for (relation:family, tails:mom)
# no vector for (relation:family, tails:bride)
# no vector for (relation:family, tails:policewoman)
# no vector for (relation:family, tails:princess)
# no vector for (relation:family, tails:her)
# no vector for (relation:family, tails:wife)
# no vector for (relation:family, tails:she)
# no vector for (relation:family, tails:woman)
# no vector for (relation:family, tails:daughters)
# no vector for (relation:family, tails:stepdaughter)
# no vector for (relation:family, tails:grandmother)
# no vector for (relation:family, tails:girl)
# no vector for (relation:family, tails:mother)
# no vector for (relation:family, tails:stepsister)
# no vector for (relation:gram1-adjective-to-adverb, tails:seriously)
# no vector for (relation:gram1-adjective-to-adverb, tails:professionally)
# no vector for (relation:gram1-adjective-to-adverb, tails:completely)
# no vector for (relation:gram1-adjective-to-adverb, tails:swiftly)
# no vector for (relation:gram1-adjective-to-adverb, tails:typically)
# no vector for (relation:gram1-adjective-to-adverb, tails:unfortunately)
# no vector for (relation:gram1-adjective-to-adverb, tails:freely)
# no vector for (relation:gram1-adjective-to-adverb, tails:rarely)
# no vector for (relation:gram1-adjective-to-adverb, tails:suddenly)
# no vector for (relation:gram1-adjective-to-adverb, tails:possibly)
# no vector for (relation:gram1-adjective-to-adverb, tails:calmly)
# no vector for (relation:gram1-adjective-to-adverb, tails:fortunately)
# no vector for (relation:gram1-adjective-to-adverb, tails:infrequently)
# no vector for (relation:gram1-adjective-to-adverb, tails:immediately)
# no vector for (relation:gram1-adjective-to-adverb, tails:cheerfully)
# no vector for (relation:gram1-adjective-to-adverb, tails:luckily)
# no vector for (relation:gram1-adjective-to-adverb, tails:quickly)
# no vector for (relation:gram1-adjective-to-adverb, tails:amazingly)
# no vector for (relation:gram1-adjective-to-adverb, tails:furiously)
# no vector for (relation:gram1-adjective-to-adverb, tails:quietly)
# no vector for (relation:gram1-adjective-to-adverb, tails:mostly)
# no vector for (relation:gram1-adjective-to-adverb, tails:apparently)
# no vector for (relation:gram1-adjective-to-adverb, tails:rapidly)
# no vector for (relation:gram1-adjective-to-adverb, tails:reluctantly)
# no vector for (relation:gram1-adjective-to-adverb, tails:occasionally)
# no vector for (relation:gram1-adjective-to-adverb, tails:obviously)
# no vector for (relation:gram1-adjective-to-adverb, tails:happily)
# no vector for (relation:gram1-adjective-to-adverb, tails:safely)
# no vector for (relation:gram1-adjective-to-adverb, tails:slowly)
# no vector for (relation:gram1-adjective-to-adverb, tails:usually)
# no vector for (relation:gram1-adjective-to-adverb, tails:precisely)
# no vector for (relation:gram1-adjective-to-adverb, tails:efficiently)
# no vector for (relation:gram2-opposite, tails:inconsistent)
# no vector for (relation:gram2-opposite, tails:unknown)
# no vector for (relation:gram2-opposite, tails:unimpressive)
# no vector for (relation:gram2-opposite, tails:inconvenient)
# no vector for (relation:gram2-opposite, tails:irrational)
# no vector for (relation:gram2-opposite, tails:unsure)
# no vector for (relation:gram2-opposite, tails:inefficient)
# no vector for (relation:gram2-opposite, tails:uninformative)
# no vector for (relation:gram2-opposite, tails:unproductive)
# no vector for (relation:gram2-opposite, tails:unlikely)
# no vector for (relation:gram2-opposite, tails:irresponsible)
# no vector for (relation:gram2-opposite, tails:illogical)
# no vector for (relation:gram2-opposite, tails:impossibly)
# no vector for (relation:gram2-opposite, tails:impossible)
# no vector for (relation:gram2-opposite, tails:unacceptable)
# no vector for (relation:gram2-opposite, tails:unclear)
# no vector for (relation:gram2-opposite, tails:unreasonable)
# no vector for (relation:gram2-opposite, tails:dishonest)
# no vector for (relation:gram2-opposite, tails:uncomfortable)
# no vector for (relation:gram2-opposite, tails:uncompetitive)
# no vector for (relation:gram2-opposite, tails:unaware)
# no vector for (relation:gram2-opposite, tails:unfortunate)
# no vector for (relation:gram2-opposite, tails:unconvincing)
# no vector for (relation:gram2-opposite, tails:uninformed)
# no vector for (relation:gram2-opposite, tails:uncertain)
# no vector for (relation:gram2-opposite, tails:unpleasant)
# no vector for (relation:gram2-opposite, tails:undecided)
# no vector for (relation:gram2-opposite, tails:unethical)
# no vector for (relation:gram2-opposite, tails:distasteful)
# no vector for (relation:gram3-comparative, tails:deeper)
# no vector for (relation:gram3-comparative, tails:greater)
# no vector for (relation:gram3-comparative, tails:safer)
# no vector for (relation:gram3-comparative, tails:harder)
# no vector for (relation:gram3-comparative, tails:higher)
# no vector for (relation:gram3-comparative, tails:larger)
# no vector for (relation:gram3-comparative, tails:tougher)
# no vector for (relation:gram3-comparative, tails:taller)
# no vector for (relation:gram3-comparative, tails:cheaper)
# no vector for (relation:gram3-comparative, tails:newer)
# no vector for (relation:gram3-comparative, tails:quicker)
# no vector for (relation:gram3-comparative, tails:bigger)
# no vector for (relation:gram3-comparative, tails:stronger)
# no vector for (relation:gram3-comparative, tails:hotter)
# no vector for (relation:gram3-comparative, tails:younger)
# no vector for (relation:gram3-comparative, tails:smarter)
# no vector for (relation:gram3-comparative, tails:smaller)
# no vector for (relation:gram3-comparative, tails:colder)
# no vector for (relation:gram3-comparative, tails:wider)
# no vector for (relation:gram3-comparative, tails:better)
# no vector for (relation:gram3-comparative, tails:louder)
# no vector for (relation:gram3-comparative, tails:sharper)
# no vector for (relation:gram3-comparative, tails:heavier)
# no vector for (relation:gram3-comparative, tails:simpler)
# no vector for (relation:gram3-comparative, tails:faster)
# no vector for (relation:gram3-comparative, tails:shorter)
# no vector for (relation:gram3-comparative, tails:longer)
# no vector for (relation:gram3-comparative, tails:cooler)
# no vector for (relation:gram3-comparative, tails:warmer)
# no vector for (relation:gram3-comparative, tails:slower)
# no vector for (relation:gram3-comparative, tails:worse)
# no vector for (relation:gram3-comparative, tails:weaker)
# no vector for (relation:gram3-comparative, tails:tighter)
# no vector for (relation:gram3-comparative, tails:brighter)
# no vector for (relation:gram3-comparative, tails:older)
# no vector for (relation:gram3-comparative, tails:easier)
# no vector for (relation:gram3-comparative, tails:lower)
# no vector for (relation:gram4-superlative, tails:darkest)
# no vector for (relation:gram4-superlative, tails:slowest)
# no vector for (relation:gram4-superlative, tails:oldest)
# no vector for (relation:gram4-superlative, tails:youngest)
# no vector for (relation:gram4-superlative, tails:coldest)
# no vector for (relation:gram4-superlative, tails:fastest)
# no vector for (relation:gram4-superlative, tails:weirdest)
# no vector for (relation:gram4-superlative, tails:largest)
# no vector for (relation:gram4-superlative, tails:easiest)
# no vector for (relation:gram4-superlative, tails:best)
# no vector for (relation:gram4-superlative, tails:widest)
# no vector for (relation:gram4-superlative, tails:sharpest)
# no vector for (relation:gram4-superlative, tails:brightest)
# no vector for (relation:gram4-superlative, tails:worst)
# no vector for (relation:gram4-superlative, tails:greatest)
# no vector for (relation:gram4-superlative, tails:tastiest)
# no vector for (relation:gram4-superlative, tails:biggest)
# no vector for (relation:gram4-superlative, tails:strongest)
# no vector for (relation:gram4-superlative, tails:tallest)
# no vector for (relation:gram4-superlative, tails:hottest)
# no vector for (relation:gram4-superlative, tails:weakest)
# no vector for (relation:gram4-superlative, tails:highest)
# no vector for (relation:gram4-superlative, tails:lowest)
# no vector for (relation:gram4-superlative, tails:luckiest)
# no vector for (relation:gram4-superlative, tails:smallest)
# no vector for (relation:gram4-superlative, tails:simplest)
# no vector for (relation:gram4-superlative, tails:smartest)
# no vector for (relation:gram4-superlative, tails:strangest)
# no vector for (relation:gram4-superlative, tails:quickest)
# no vector for (relation:gram4-superlative, tails:warmest)
# no vector for (relation:gram4-superlative, tails:shortest)
# no vector for (relation:gram4-superlative, tails:sweetest)
# no vector for (relation:gram4-superlative, tails:coolest)
# no vector for (relation:gram4-superlative, tails:longest)
# no vector for (relation:gram5-present-participle, tails:enhancing)
# no vector for (relation:gram5-present-participle, tails:listening)
# no vector for (relation:gram5-present-participle, tails:implementing)
# no vector for (relation:gram5-present-participle, tails:going)
# no vector for (relation:gram5-present-participle, tails:debugging)
# no vector for (relation:gram5-present-participle, tails:swimming)
# no vector for (relation:gram5-present-participle, tails:discovering)
# no vector for (relation:gram5-present-participle, tails:looking)
# no vector for (relation:gram5-present-participle, tails:playing)
# no vector for (relation:gram5-present-participle, tails:describing)
# no vector for (relation:gram5-present-participle, tails:writing)
# no vector for (relation:gram5-present-participle, tails:generating)
# no vector for (relation:gram5-present-participle, tails:jumping)
# no vector for (relation:gram5-present-participle, tails:inventing)
# no vector for (relation:gram5-present-participle, tails:walking)
# no vector for (relation:gram5-present-participle, tails:decreasing)
# no vector for (relation:gram5-present-participle, tails:running)
# no vector for (relation:gram5-present-participle, tails:slowing)
# no vector for (relation:gram5-present-participle, tails:coding)
# no vector for (relation:gram5-present-participle, tails:thinking)
# no vector for (relation:gram5-present-participle, tails:seeing)
# no vector for (relation:gram5-present-participle, tails:increasing)
# no vector for (relation:gram5-present-participle, tails:saying)
# no vector for (relation:gram5-present-participle, tails:singing)
# no vector for (relation:gram5-present-participle, tails:sitting)
# no vector for (relation:gram5-present-participle, tails:reading)
# no vector for (relation:gram5-present-participle, tails:flying)
# no vector for (relation:gram5-present-participle, tails:screaming)
# no vector for (relation:gram5-present-participle, tails:vanishing)
# no vector for (relation:gram5-present-participle, tails:dancing)
# no vector for (relation:gram5-present-participle, tails:shuffling)
# no vector for (relation:gram5-present-participle, tails:moving)
# no vector for (relation:gram5-present-participle, tails:predicting)
# no vector for (relation:gram6-nationality-adjective, tails:norwegian)
# no vector for (relation:gram6-nationality-adjective, tails:peruvian)
# no vector for (relation:gram6-nationality-adjective, tails:spanish)
# no vector for (relation:gram6-nationality-adjective, tails:slovakian)
# no vector for (relation:gram6-nationality-adjective, tails:croatian)
# no vector for (relation:gram6-nationality-adjective, tails:polish)
# no vector for (relation:gram6-nationality-adjective, tails:maltese)
# no vector for (relation:gram6-nationality-adjective, tails:greek)
# no vector for (relation:gram6-nationality-adjective, tails:macedonian)
# no vector for (relation:gram6-nationality-adjective, tails:ukrainian)
# no vector for (relation:gram6-nationality-adjective, tails:colombian)
# no vector for (relation:gram6-nationality-adjective, tails:austrian)
# no vector for (relation:gram6-nationality-adjective, tails:swiss)
# no vector for (relation:gram6-nationality-adjective, tails:australian)
# no vector for (relation:gram6-nationality-adjective, tails:russian)
# no vector for (relation:gram6-nationality-adjective, tails:english)
# no vector for (relation:gram6-nationality-adjective, tails:argentinean)
# no vector for (relation:gram6-nationality-adjective, tails:cambodian)
# no vector for (relation:gram6-nationality-adjective, tails:egyptian)
# no vector for (relation:gram6-nationality-adjective, tails:german)
# no vector for (relation:gram6-nationality-adjective, tails:chinese)
# no vector for (relation:gram6-nationality-adjective, tails:thai)
# no vector for (relation:gram6-nationality-adjective, tails:danish)
# no vector for (relation:gram6-nationality-adjective, tails:french)
# no vector for (relation:gram6-nationality-adjective, tails:swedish)
# no vector for (relation:gram6-nationality-adjective, tails:brazilian)
# no vector for (relation:gram6-nationality-adjective, tails:irish)
# no vector for (relation:gram6-nationality-adjective, tails:korean)
# no vector for (relation:gram6-nationality-adjective, tails:belorussian)
# no vector for (relation:gram6-nationality-adjective, tails:dutch)
# no vector for (relation:gram6-nationality-adjective, tails:japanese)
# no vector for (relation:gram6-nationality-adjective, tails:chilean)
# no vector for (relation:gram6-nationality-adjective, tails:italian)
# no vector for (relation:gram6-nationality-adjective, tails:albanian)
# no vector for (relation:gram6-nationality-adjective, tails:indian)
# no vector for (relation:gram6-nationality-adjective, tails:moldovan)
# no vector for (relation:gram6-nationality-adjective, tails:mexican)
# no vector for (relation:gram6-nationality-adjective, tails:bulgarian)
# no vector for (relation:gram6-nationality-adjective, tails:icelandic)
# no vector for (relation:gram6-nationality-adjective, tails:israeli)
# no vector for (relation:gram6-nationality-adjective, tails:portuguese)
# no vector for (relation:gram7-past-tense, tails:jumped)
# no vector for (relation:gram7-past-tense, tails:moved)
# no vector for (relation:gram7-past-tense, tails:shrank)
# no vector for (relation:gram7-past-tense, tails:hid)
# no vector for (relation:gram7-past-tense, tails:slowed)
# no vector for (relation:gram7-past-tense, tails:read)
# no vector for (relation:gram7-past-tense, tails:increased)
# no vector for (relation:gram7-past-tense, tails:predicted)
# no vector for (relation:gram7-past-tense, tails:fed)
# no vector for (relation:gram7-past-tense, tails:struck)
# no vector for (relation:gram7-past-tense, tails:generated)
# no vector for (relation:gram7-past-tense, tails:danced)
# no vector for (relation:gram7-past-tense, tails:played)
# no vector for (relation:gram7-past-tense, tails:hit)
# no vector for (relation:gram7-past-tense, tails:went)
# no vector for (relation:gram7-past-tense, tails:fell)
# no vector for (relation:gram7-past-tense, tails:thought)
# no vector for (relation:gram7-past-tense, tails:listened)
# no vector for (relation:gram7-past-tense, tails:vanished)
# no vector for (relation:gram7-past-tense, tails:screamed)
# no vector for (relation:gram7-past-tense, tails:described)
# no vector for (relation:gram7-past-tense, tails:walked)
# no vector for (relation:gram7-past-tense, tails:implemented)
# no vector for (relation:gram7-past-tense, tails:sang)
# no vector for (relation:gram7-past-tense, tails:sold)
# no vector for (relation:gram7-past-tense, tails:flew)
# no vector for (relation:gram7-past-tense, tails:took)
# no vector for (relation:gram7-past-tense, tails:enhanced)
# no vector for (relation:gram7-past-tense, tails:spent)
# no vector for (relation:gram7-past-tense, tails:decreased)
# no vector for (relation:gram7-past-tense, tails:slept)
# no vector for (relation:gram7-past-tense, tails:paid)
# no vector for (relation:gram7-past-tense, tails:ran)
# no vector for (relation:gram7-past-tense, tails:looked)
# no vector for (relation:gram7-past-tense, tails:said)
# no vector for (relation:gram7-past-tense, tails:sat)
# no vector for (relation:gram7-past-tense, tails:wrote)
# no vector for (relation:gram7-past-tense, tails:swam)
# no vector for (relation:gram7-past-tense, tails:saw)
# no vector for (relation:gram7-past-tense, tails:knew)
# no vector for (relation:gram8-plural, tails:pears)
# no vector for (relation:gram8-plural, tails:women)
# no vector for (relation:gram8-plural, tails:roads)
# no vector for (relation:gram8-plural, tails:lions)
# no vector for (relation:gram8-plural, tails:mangoes)
# no vector for (relation:gram8-plural, tails:cats)
# no vector for (relation:gram8-plural, tails:birds)
# no vector for (relation:gram8-plural, tails:dogs)
# no vector for (relation:gram8-plural, tails:children)
# no vector for (relation:gram8-plural, tails:pigs)
# no vector for (relation:gram8-plural, tails:elephants)
# no vector for (relation:gram8-plural, tails:eyes)
# no vector for (relation:gram8-plural, tails:cars)
# no vector for (relation:gram8-plural, tails:bottles)
# no vector for (relation:gram8-plural, tails:donkeys)
# no vector for (relation:gram8-plural, tails:dreams)
# no vector for (relation:gram8-plural, tails:onions)
# no vector for (relation:gram8-plural, tails:melons)
# no vector for (relation:gram8-plural, tails:fingers)
# no vector for (relation:gram8-plural, tails:hands)
# no vector for (relation:gram8-plural, tails:eagles)
# no vector for (relation:gram8-plural, tails:goats)
# no vector for (relation:gram8-plural, tails:pineapples)
# no vector for (relation:gram8-plural, tails:snakes)
# no vector for (relation:gram8-plural, tails:bananas)
# no vector for (relation:gram8-plural, tails:computers)
# no vector for (relation:gram8-plural, tails:cows)
# no vector for (relation:gram8-plural, tails:buildings)
# no vector for (relation:gram8-plural, tails:clouds)
# no vector for (relation:gram8-plural, tails:rats)
# no vector for (relation:gram8-plural, tails:machines)
# no vector for (relation:gram8-plural, tails:colors)
# no vector for (relation:gram8-plural, tails:monkeys)
# no vector for (relation:gram8-plural, tails:dollars)
# no vector for (relation:gram8-plural, tails:mice)
# no vector for (relation:gram8-plural, tails:horses)
# no vector for (relation:gram8-plural, tails:men)
# no vector for (relation:gram9-plural-verbs, tails:says)
# no vector for (relation:gram9-plural-verbs, tails:sees)
# no vector for (relation:gram9-plural-verbs, tails:eats)
# no vector for (relation:gram9-plural-verbs, tails:searches)
# no vector for (relation:gram9-plural-verbs, tails:sits)
# no vector for (relation:gram9-plural-verbs, tails:works)
# no vector for (relation:gram9-plural-verbs, tails:shuffles)
# no vector for (relation:gram9-plural-verbs, tails:writes)
# no vector for (relation:gram9-plural-verbs, tails:estimates)
# no vector for (relation:gram9-plural-verbs, tails:talks)
# no vector for (relation:gram9-plural-verbs, tails:vanishes)
# no vector for (relation:gram9-plural-verbs, tails:implements)
# no vector for (relation:gram9-plural-verbs, tails:decreases)
# no vector for (relation:gram9-plural-verbs, tails:thinks)
# no vector for (relation:gram9-plural-verbs, tails:sings)
# no vector for (relation:gram9-plural-verbs, tails:describes)
# no vector for (relation:gram9-plural-verbs, tails:provides)
# no vector for (relation:gram9-plural-verbs, tails:listens)
# no vector for (relation:gram9-plural-verbs, tails:walks)
# no vector for (relation:gram9-plural-verbs, tails:goes)
# no vector for (relation:gram9-plural-verbs, tails:increases)
# no vector for (relation:gram9-plural-verbs, tails:speaks)
# no vector for (relation:gram9-plural-verbs, tails:enhances)
# no vector for (relation:gram9-plural-verbs, tails:slows)
# no vector for (relation:gram9-plural-verbs, tails:swims)
# no vector for (relation:gram9-plural-verbs, tails:predicts)
# no vector for (relation:gram9-plural-verbs, tails:plays)
# no vector for (relation:gram9-plural-verbs, tails:finds)
# no vector for (relation:gram9-plural-verbs, tails:generates)
# no vector for (relation:gram9-plural-verbs, tails:screams)

# %%
dataset2['tails']
# Out:
# {0: 'spain',
#  1: 'canada',
#  2: 'egypt',
#  3: 'france',
#  4: 'switzerland',
#  5: 'iraq',
#  6: 'italy',
#  7: 'thailand',
#  8: 'afghanistan',
#  9: 'japan',
#  10: 'greece',
#  11: 'germany',
#  12: 'russia',
#  13: 'vietnam',
#  14: 'china',
#  15: 'norway',
#  16: 'pakistan',
#  17: 'sweden',
#  18: 'england',
#  19: 'iran',
#  20: 'cuba',
#  21: 'australia',
#  22: 'finland',
#  23: 'chile',
#  24: 'jordan',
#  25: 'nepal',
#  26: 'nicaragua',
#  27: 'madagascar',
#  28: 'sudan',
#  29: 'gabon',
#  30: 'slovenia',
#  31: 'malta',
#  32: 'rwanda',
#  33: 'germany',
#  34: 'greece',
#  35: 'bahamas',
#  36: 'georgia',
#  37: 'mozambique',
#  38: 'zimbabwe',
#  39: 'kyrgyzstan',
#  40: 'syria',
#  41: 'kazakhstan',
#  42: 'guinea',
#  43: 'liberia',
#  44: 'canada',
#  45: 'eritrea',
#  46: 'hungary',
#  47: 'thailand',
#  48: 'serbia',
#  49: 'china',
#  50: 'ukraine',
#  51: 'iraq',
#  52: 'uzbekistan',
#  53: 'jamaica',
#  54: 'libya',
#  55: 'vietnam',
#  56: 'fiji',
#  57: 'angola',
#  58: 'ireland',
#  59: 'portugal',
#  60: 'tajikistan',
#  61: 'poland',
#  62: 'uruguay',
#  63: 'denmark',
#  64: 'peru',
#  65: 'bahrain',
#  66: 'turkey',
#  67: 'kenya',
#  68: 'romania',
#  69: 'dominica',
#  70: 'philippines',
#  71: 'nigeria',
#  72: 'malawi',
#  73: 'belarus',
#  74: 'tuvalu',
#  75: 'qatar',
#  76: 'switzerland',
#  77: 'burundi',
#  78: 'uganda',
#  79: 'somalia',
#  80: 'azerbaijan',
#  81: 'honduras',
#  82: 'lithuania',
#  83: 'gambia',
#  84: 'turkmenistan',
#  85: 'suriname',
#  86: 'egypt',
#  87: 'ecuador',
#  88: 'macedonia',
#  89: 'belgium',
#  90: 'ghana',
#  91: 'belize',
#  92: 'venezuela',
#  93: 'afghanistan',
#  94: 'armenia',
#  95: 'norway',
#  96: 'pakistan',
#  97: 'guyana',
#  98: 'albania',
#  99: 'lebanon',
#  100: 'bhutan',
#  101: 'namibia',
#  102: 'niger',
#  103: 'austria',
#  104: 'moldova',
#  105: 'mauritania',
#  106: 'greenland',
#  107: 'croatia',
#  108: 'russia',
#  109: 'japan',
#  110: 'cuba',
#  111: 'morocco',
#  112: 'finland',
#  113: 'slovakia',
#  114: 'france',
#  115: 'bulgaria',
#  116: 'australia',
#  117: 'montenegro',
#  118: 'samoa',
#  119: 'sweden',
#  120: 'botswana',
#  121: 'oman',
#  122: 'algeria',
#  123: 'england',
#  124: 'spain',
#  125: 'indonesia',
#  126: 'liechtenstein',
#  127: 'taiwan',
#  128: 'italy',
#  129: 'cyprus',
#  130: 'estonia',
#  131: 'latvia',
#  132: 'mali',
#  133: 'senegal',
#  134: 'laos',
#  135: 'bangladesh',
#  136: 'zambia',
#  137: 'iran',
#  138: 'tunisia',
#  139: 'texas',
#  140: 'michigan',
#  141: 'oregon',
#  142: 'nebraska',
#  143: 'texas',
#  144: 'texas',
#  145: 'california',
#  146: 'pennsylvania',
#  147: 'florida',
#  148: 'texas',
#  149: 'wisconsin',
#  150: 'colorado',
#  151: 'florida',
#  152: 'california',
#  153: 'kansas',
#  154: 'california',
#  155: 'arizona',
#  156: 'california',
#  157: 'arizona',
#  158: 'hawaii',
#  159: 'california',
#  160: 'texas',
#  161: 'kentucky',
#  162: 'massachusetts',
#  163: 'tennessee',
#  164: 'georgia',
#  165: 'louisiana',
#  166: 'california',
#  167: 'washington',
#  168: 'ohio',
#  169: 'florida',
#  170: 'florida',
#  171: 'alabama',
#  172: 'pennsylvania',
#  173: 'arizona',
#  174: 'wisconsin',
#  175: 'minnesota',
#  176: 'texas',
#  177: 'texas',
#  178: 'nevada',
#  179: 'indiana',
#  180: 'arizona',
#  181: 'texas',
#  182: 'maryland',
#  183: 'florida',
#  184: 'california',
#  185: 'texas',
#  186: 'illinois',
#  187: 'arizona',
#  188: 'alaska',
#  189: 'nevada',
#  190: 'texas',
#  191: 'ohio',
#  192: 'washington',
#  193: 'california',
#  194: 'florida',
#  195: 'tennessee',
#  196: 'california',
#  197: 'kentucky',
#  198: 'california',
#  199: 'arizona',
#  200: 'massachusetts',
#  201: 'washington',
#  202: 'california',
#  203: 'ohio',
#  204: 'ohio',
#  205: 'california',
#  206: 'oklahoma',
#  207: 'dollar',
#  208: 'ringgit',
#  209: 'dollar',
#  210: 'baht',
#  211: 'litas',
#  212: 'yen',
#  213: 'forint',
#  214: 'peso',
#  215: 'dinar',
#  216: 'dram',
#  217: 'naira',
#  218: 'euro',
#  219: 'lats',
#  220: 'denar',
#  221: 'kwanza',
#  222: 'rial',
#  223: 'riel',
#  224: 'zloty',
#  225: 'ruble',
#  226: 'krone',
#  227: 'rupee',
#  228: 'won',
#  229: 'lev',
#  230: 'peso',
#  231: 'dong',
#  232: 'leu',
#  233: 'hryvnia',
#  234: 'real',
#  235: 'kuna',
#  236: 'krona',
#  237: 'queen',
#  238: 'daughter',
#  239: 'aunt',
#  240: 'sister',
#  241: 'stepmother',
#  242: 'grandma',
#  243: 'niece',
#  244: 'granddaughter',
#  245: 'sisters',
#  246: 'mom',
#  247: 'bride',
#  248: 'policewoman',
#  249: 'princess',
#  250: 'her',
#  251: 'wife',
#  252: 'she',
#  253: 'woman',
#  254: 'daughters',
#  255: 'stepdaughter',
#  256: 'grandmother',
#  257: 'girl',
#  258: 'mother',
#  259: 'stepsister',
#  260: 'seriously',
#  261: 'professionally',
#  262: 'completely',
#  263: 'swiftly',
#  264: 'typically',
#  265: 'unfortunately',
#  266: 'freely',
#  267: 'rarely',
#  268: 'suddenly',
#  269: 'possibly',
#  270: 'calmly',
#  271: 'fortunately',
#  272: 'infrequently',
#  273: 'immediately',
#  274: 'cheerfully',
#  275: 'luckily',
#  276: 'quickly',
#  277: 'amazingly',
#  278: 'furiously',
#  279: 'quietly',
#  280: 'mostly',
#  281: 'apparently',
#  282: 'rapidly',
#  283: 'reluctantly',
#  284: 'occasionally',
#  285: 'obviously',
#  286: 'happily',
#  287: 'safely',
#  288: 'slowly',
#  289: 'usually',
#  290: 'precisely',
#  291: 'efficiently',
#  292: 'inconsistent',
#  293: 'unknown',
#  294: 'unimpressive',
#  295: 'inconvenient',
#  296: 'irrational',
#  297: 'unsure',
#  298: 'inefficient',
#  299: 'uninformative',
#  300: 'unproductive',
#  301: 'unlikely',
#  302: 'irresponsible',
#  303: 'illogical',
#  304: 'impossibly',
#  305: 'impossible',
#  306: 'unacceptable',
#  307: 'unclear',
#  308: 'unreasonable',
#  309: 'dishonest',
#  310: 'uncomfortable',
#  311: 'uncompetitive',
#  312: 'unaware',
#  313: 'unfortunate',
#  314: 'unconvincing',
#  315: 'uninformed',
#  316: 'uncertain',
#  317: 'unpleasant',
#  318: 'undecided',
#  319: 'unethical',
#  320: 'distasteful',
#  321: 'deeper',
#  322: 'greater',
#  323: 'safer',
#  324: 'harder',
#  325: 'higher',
#  326: 'larger',
#  327: 'tougher',
#  328: 'taller',
#  329: 'cheaper',
#  330: 'newer',
#  331: 'quicker',
#  332: 'bigger',
#  333: 'stronger',
#  334: 'hotter',
#  335: 'younger',
#  336: 'smarter',
#  337: 'smaller',
#  338: 'colder',
#  339: 'wider',
#  340: 'better',
#  341: 'louder',
#  342: 'sharper',
#  343: 'heavier',
#  344: 'simpler',
#  345: 'faster',
#  346: 'shorter',
#  347: 'longer',
#  348: 'cooler',
#  349: 'warmer',
#  350: 'slower',
#  351: 'worse',
#  352: 'weaker',
#  353: 'tighter',
#  354: 'brighter',
#  355: 'older',
#  356: 'easier',
#  357: 'lower',
#  358: 'darkest',
#  359: 'slowest',
#  360: 'oldest',
#  361: 'youngest',
#  362: 'coldest',
#  363: 'fastest',
#  364: 'weirdest',
#  365: 'largest',
#  366: 'easiest',
#  367: 'best',
#  368: 'widest',
#  369: 'sharpest',
#  370: 'brightest',
#  371: 'worst',
#  372: 'greatest',
#  373: 'tastiest',
#  374: 'biggest',
#  375: 'strongest',
#  376: 'tallest',
#  377: 'hottest',
#  378: 'weakest',
#  379: 'highest',
#  380: 'lowest',
#  381: 'luckiest',
#  382: 'smallest',
#  383: 'simplest',
#  384: 'smartest',
#  385: 'strangest',
#  386: 'quickest',
#  387: 'warmest',
#  388: 'shortest',
#  389: 'sweetest',
#  390: 'coolest',
#  391: 'longest',
#  392: 'enhancing',
#  393: 'listening',
#  394: 'implementing',
#  395: 'going',
#  396: 'debugging',
#  397: 'swimming',
#  398: 'discovering',
#  399: 'looking',
#  400: 'playing',
#  401: 'describing',
#  402: 'writing',
#  403: 'generating',
#  404: 'jumping',
#  405: 'inventing',
#  406: 'walking',
#  407: 'decreasing',
#  408: 'running',
#  409: 'slowing',
#  410: 'coding',
#  411: 'thinking',
#  412: 'seeing',
#  413: 'increasing',
#  414: 'saying',
#  415: 'singing',
#  416: 'sitting',
#  417: 'reading',
#  418: 'flying',
#  419: 'screaming',
#  420: 'vanishing',
#  421: 'dancing',
#  422: 'shuffling',
#  423: 'moving',
#  424: 'predicting',
#  425: 'norwegian',
#  426: 'peruvian',
#  427: 'spanish',
#  428: 'slovakian',
#  429: 'croatian',
#  430: 'polish',
#  431: 'maltese',
#  432: 'greek',
#  433: 'macedonian',
#  434: 'ukrainian',
#  435: 'colombian',
#  436: 'austrian',
#  437: 'swiss',
#  438: 'australian',
#  439: 'russian',
#  440: 'english',
#  441: 'argentinean',
#  442: 'cambodian',
#  443: 'egyptian',
#  444: 'german',
#  445: 'chinese',
#  446: 'thai',
#  447: 'danish',
#  448: 'french',
#  449: 'swedish',
#  450: 'brazilian',
#  451: 'irish',
#  452: 'korean',
#  453: 'belorussian',
#  454: 'dutch',
#  455: 'japanese',
#  456: 'chilean',
#  457: 'italian',
#  458: 'albanian',
#  459: 'indian',
#  460: 'moldovan',
#  461: 'mexican',
#  462: 'bulgarian',
#  463: 'icelandic',
#  464: 'israeli',
#  465: 'portuguese',
#  466: 'jumped',
#  467: 'moved',
#  468: 'shrank',
#  469: 'hid',
#  470: 'slowed',
#  471: 'read',
#  472: 'increased',
#  473: 'predicted',
#  474: 'fed',
#  475: 'struck',
#  476: 'generated',
#  477: 'danced',
#  478: 'played',
#  479: 'hit',
#  480: 'went',
#  481: 'fell',
#  482: 'thought',
#  483: 'listened',
#  484: 'vanished',
#  485: 'screamed',
#  486: 'described',
#  487: 'walked',
#  488: 'implemented',
#  489: 'sang',
#  490: 'sold',
#  491: 'flew',
#  492: 'took',
#  493: 'enhanced',
#  494: 'spent',
#  495: 'decreased',
#  496: 'slept',
#  497: 'paid',
#  498: 'ran',
#  499: 'looked',
#  500: 'said',
#  501: 'sat',
#  502: 'wrote',
#  503: 'swam',
#  504: 'saw',
#  505: 'knew',
#  506: 'pears',
#  507: 'women',
#  508: 'roads',
#  509: 'lions',
#  510: 'mangoes',
#  511: 'cats',
#  512: 'birds',
#  513: 'dogs',
#  514: 'children',
#  515: 'pigs',
#  516: 'elephants',
#  517: 'eyes',
#  518: 'cars',
#  519: 'bottles',
#  520: 'donkeys',
#  521: 'dreams',
#  522: 'onions',
#  523: 'melons',
#  524: 'fingers',
#  525: 'hands',
#  526: 'eagles',
#  527: 'goats',
#  528: 'pineapples',
#  529: 'snakes',
#  530: 'bananas',
#  531: 'computers',
#  532: 'cows',
#  533: 'buildings',
#  534: 'clouds',
#  535: 'rats',
#  536: 'machines',
#  537: 'colors',
#  538: 'monkeys',
#  539: 'dollars',
#  540: 'mice',
#  541: 'horses',
#  542: 'men',
#  543: 'says',
#  544: 'sees',
#  545: 'eats',
#  546: 'searches',
#  547: 'sits',
#  548: 'works',
#  549: 'shuffles',
#  550: 'writes',
#  551: 'estimates',
#  552: 'talks',
#  553: 'vanishes',
#  554: 'implements',
#  555: 'decreases',
#  556: 'thinks',
#  557: 'sings',
#  558: 'describes',
#  559: 'provides',
#  560: 'listens',
#  561: 'walks',
#  562: 'goes',
#  563: 'increases',
#  564: 'speaks',
#  565: 'enhances',
#  566: 'slows',
#  567: 'swims',
#  568: 'predicts',
#  569: 'plays',
#  570: 'finds',
#  571: 'generates',
#  572: 'screams'}
